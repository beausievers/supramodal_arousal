# %%
# %matplotlib inline

import itertools
import copy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
from bambi import Model
import pymc3 as pm
from scipy.stats import zscore
from sklearn import model_selection
from sklearn.metrics import roc_curve, roc_auc_score
import tabulate

# %% [markdown]
# ## Functions for prediction and cross-validation
#
# Note: the prediction method I use here is not efficient and is a bit of a kludge

# %%
def get_terms(trace):
    terms = trace.varnames
    exclude = ['_sd_log__', '_offset', '_sd']
    for e in exclude:
        terms = [t for t in terms if t[-len(e):] != e]
    return terms

# %%
def get_group_id_index(result, varname, group_id):
    varname_group_string = f"{varname}[{group_id}]"
    return result.level_dict[varname].index(varname_group_string)

# %%
def get_weights(result, trace, varnames, group_dict=None):
    weights = []
    for v in varnames:
        if '|' not in v:
            weights.append(trace.get_values(v).mean())
        else:
            group_name = v.split('|')[1]
            group_id = group_dict[group_name]
            group_id_index = get_group_id_index(result, v, group_id)
            weights.append(trace.get_values(v)[:, group_id_index].mean())
    return weights

# %%
def df_add_term_cols(df, terms):
    """Appends interaction columns to a Pandas dataframe specified by terms. 
    
    When creating new columns, converts bool series to int. Returns new dataframe.
    """
    new_df = df.copy()
    terms = [t for t in terms if '|' not in t]
    terms = [t for t in terms if t != 'Intercept']
    terms = [t for t in terms if t[0:2] != '1|']

    for term in terms:
        col_names = term.split(':')
        
        # Create interaction term column
        if len(col_names) > 1:
            series = [new_df[col_name] for col_name in col_names]
            for i, s in enumerate(series):
                if s.dtype == bool:
                    series[i] = series[i].astype(int)
            new_df[term] = np.prod(np.array(series).T, axis=1)
    return new_df

# %%
def invlogit(x): return 1 / (1 + np.exp(-x))

# %%
def predict(row, terms, result, trace):
    subID = row['subID']
    weights = get_weights(result, trace, terms, {'subID': subID})
    terms_fixed = [t for t in terms if '|' not in t]    
    
    # Separate fixed and random effects, then adjust fixed effects weights by adding
    # random effects offsets
    w = np.array([weights[0:int(len(weights)/2)], weights[int(len(weights)/2):]]).sum(axis=0)
    x = np.hstack([1, row[terms_fixed[1:]].as_matrix()])
    prob = invlogit(np.sum(x * w))
    return prob

# %%
def bambi_cv(
    df, 
    model_string, 
    model_dict, 
    n_splits=5, 
    dv='highArousal', 
    grouping_var='subID'
):
    fold_acc = []
    fold_results = []
    fold_models = []
    fold_roc = []
    fold_auc = []

    cv = model_selection.StratifiedKFold(n_splits=n_splits, shuffle=True)

    for train_ix, test_ix in cv.split(df, df[grouping_var]):
        df_train = df.loc[train_ix, :]
        df_train.reset_index(drop=True)
        m = Model(df_train)
        r = m.fit(
            model_string, **model_dict
        )

        terms = get_terms(m.backend.trace)
        #df_sm = df.loc[:, ['subID', 'bin', 'areaRatio', 'boundingBoxArea', 'highArousal']]
        df_sm_ex = df_add_term_cols(df, terms)
        df_sm_ex_test = df_sm_ex.loc[test_ix, :]

        probs = []
        for _, row in df_sm_ex_test.iterrows():
            probs.append(predict(row, terms, r, m.backend.trace))
        preds = np.array(probs) > 0.5

        df_sm_ex_test['pred'] = preds

        fold_roc.append(roc_curve(df_sm_ex_test[dv], probs))
        fold_auc.append(roc_auc_score(df_sm_ex_test[dv], probs))
        fold_acc.append(np.mean(df_sm_ex_test['pred'] == df_sm_ex_test[dv]))
        fold_results.append(r)
        fold_models.append(m)
        
    return (fold_acc, fold_results, fold_models, fold_roc, fold_auc)

# %% [markdown]
# ## Functions for plotting

# %%
from logistic import plot_roc_cv

# %%
def plot_fixed(param, summary_df, data_df, steps=100, 
               x_label=None, y_label=None, title=None, ax=None):
    sns.set_style('ticks')
    sns.set_palette('muted')
    
    fsize = 14
    titlesize = 18

    x_min = data_df[param].min()
    x_max = data_df[param].max()
    
    summary_param = param
        
    if type(x_min) is bool or type(x_min) is np.bool_:
        x_min = float(x_min)
        x_max = float(x_max)
        summary_param += '[T.True]'
    
    slope_mean = summary_df.loc[summary_param]['mean']
    slope_lower = summary_df.loc[summary_param]['hpd0.95_lower']
    slope_upper = summary_df.loc[summary_param]['hpd0.95_upper']

    i_mean = summary_df.loc['Intercept']['mean']
    i_lower = summary_df.loc['Intercept']['hpd0.95_lower']
    i_upper = summary_df.loc['Intercept']['hpd0.95_upper']

    xs = np.linspace(np.floor(x_min), np.ceil(x_max), steps)

    X = np.hstack([np.array([1] * len(xs))[:,None],
                   xs[:,None]])
    yhat = invlogit(np.dot(X, np.vstack([i_mean, slope_mean]))).T[0]
    yhat_lower = invlogit(np.dot(X, np.vstack([i_lower, slope_lower]))).T[0]
    yhat_upper = invlogit(np.dot(X, np.vstack([i_upper, slope_upper]))).T[0]

    if ax is None:
        fig, ax = plt.subplots(figsize=(7,5))
    
    ax.tick_params(labelsize=fsize)
    
    ax.plot(xs, yhat, color='black')
    ax.fill_between(xs, yhat_upper, yhat_lower, color="gray", alpha=0.4)
    
    if x_label is None:
        x_label = param
    if y_label is None:
        y_label = f"p(highArousal | {param})"
        
    ax.set_xlabel(x_label, fontsize=fsize)
    ax.set_ylabel(y_label, fontsize=fsize)
    
    if title is not None:
        ax.set_title(title, fontsize=titlesize)
    
    sns.despine(bottom=True, left=True)

# %%
def plot_full_cv(fold_results, fold_roc, param, data_df, 
                x_label=None, y_label=None, title=None, dpi=None):
    f = plt.figure(figsize=(10,3), dpi=dpi)
    plt.subplots_adjust(wspace=0.45)
    gs = gridspec.GridSpec(1, 2, width_ratios=[2,1])
    ax0 = plt.subplot(gs[0])
    ax1 = plt.subplot(gs[1])
    
    # This is a terrible kludge to work around a possible bambi bug
    for res in fold_results:
        res.model.family.name = 'b-boy'
    
    summary_dfs = [res.summary() for res in fold_results]
    df_concat = pd.concat(summary_dfs)
    mean_df = df_concat.groupby(df_concat.index).mean()
    
    plot_fixed(param, mean_df, data_df, x_label=x_label, y_label=y_label, title=title, ax=ax0)
    plot_roc_cv(fold_roc, display_cv_folds=False, ax=ax1)

# %% [markdown]
# ## Table generation

# %%
table_headers = ['M', 'SD', 'CI lower', 'CI upper', 'Effective N', 'Gelman-Rubin']

# %%
def summary_table(results):
    all_summaries = [res.summary() for res in results]
    all_summaries_concat = pd.concat(all_summaries)
    all_summaries_mean = all_summaries_concat.groupby(all_summaries_concat.index).mean().round(2)
    table = tabulate.tabulate(
        all_summaries_mean,
        headers=table_headers, 
        tablefmt='pipe'
    ).replace('|subID', '\|subID').replace('[T.True]', '')
    return table

# %% [markdown]
# ## Load data

# %%
neg = pd.read_csv('../data/study_3/negative.csv')
pos = pd.read_csv('../data/study_3/positive.csv')
merged = neg.append(pos, ignore_index=True)

# %%
merged['subID'].value_counts()
# Out:
# 47    520
# 52    520
# 39    520
# 23    520
# 7     520
# 54    520
# 38    520
# 53    520
# 37    520
# 35    520
# 31    520
# 19    520
# 50    520
# 34    520
# 18    520
# 17    520
# 1     520
# 32    520
# 55    520
# 8     520
# 40    520
# 27    520
# 15    520
# 46    520
# 14    520
# 29    520
# 28    520
# 12    520
# 56    520
# 43    520
# 11    520
# 42    520
# 26    520
# 57    520
# 41    520
# 16    520
# 59    416
# 44    286
# 22    156
# 10    156
# Name: subID, dtype: int64

# %%
init_len_neg = neg.shape[0]
neg = neg.drop(neg[neg['rating'] == 'INAUDIBLE'].index)
dropped_neg = init_len_neg - neg.shape[0]
neg = neg.reset_index(drop=True)
print(f"Dropped {dropped_neg} rows from neg due to 'INAUDIBLE'. Final shape: {neg.shape}")

init_len_pos = pos.shape[0]
pos = pos.drop(pos[pos['rating'] == 'INAUDIBLE'].index)
dropped_pos = init_len_pos - pos.shape[0]
pos = pos.reset_index(drop=True)
print(f"Dropped {dropped_pos} rows from pos due to 'INAUDIBLE'. Final shape: {pos.shape}")
# Out:
# Dropped 73 rows from neg due to 'INAUDIBLE'. Final shape: (9989, 12)
# Dropped 31 rows from pos due to 'INAUDIBLE'. Final shape: (9641, 12)

# %%
pos['modalitySound'] = pos['stimType'] == 'sound'
neg['modalitySound'] = neg['stimType'] == 'sound'

vis_neg = neg[neg['stimType'] == 'image']
aud_neg = neg[neg['stimType'] == 'sound']
vis_pos = pos[pos['stimType'] == 'image']
aud_pos = pos[pos['stimType'] == 'sound']

merged = neg.append(pos, ignore_index=True)
merged['highArousal'] = ((merged['rating'] == 'Angry') | (merged['rating'] == 'Excited')).astype(bool)
merged['positiveValence'] = ((merged['rating'] == 'Excited') | (merged['rating'] == 'Peaceful')).astype(bool)
#merged = pd.get_dummies(merged, columns=['stimType'], drop_first=False).head()

vis = vis_neg.append(vis_pos, ignore_index=True)
vis['highArousal'] = ((vis['rating'] == 'Angry') | (vis['rating'] == 'Excited')).astype(bool)
vis['positiveValence'] = ((vis['rating'] == 'Excited') | (vis['rating'] == 'Peaceful')).astype(bool)

aud = aud_neg.append(aud_pos, ignore_index=True)
aud['highArousal'] = ((aud['rating'] == 'Angry') | (aud['rating'] == 'Excited')).astype(int)
aud['positiveValence'] = ((aud['rating'] == 'Excited') | (aud['rating'] == 'Peaceful')).astype(bool)

# %%
for df in [merged, vis, aud]:
    for col in ['bin',   # is this the right thing to do for bin?
                'corners', 
                'spectralCentroid', 
                'boundingBoxArea', 
                'areaRatio', 
                'duration', 
                'numOnsets', 
                'onsetStrength']:
        df[col] = (df[col] - df[col].mean()) / df[col].std()

# %%
merged.head()
# Out:
#    subID stimFile stimType       bin   corners  spectralCentroid rating  \
# 0      1      LC0    image -0.543477 -0.534524               NaN  Angry
# 1      1     PS14    image -0.811623 -0.801773               NaN    Sad
# 2      1     ROS3    sound -1.616060       NaN         -1.528469  Angry
# 3      1     LC14    image -1.079768 -1.069022               NaN    Sad
# 4      1      PS3    image -0.007185 -0.000027               NaN    Sad
#
#    boundingBoxArea  areaRatio  duration  numOnsets  onsetStrength  \
# 0        -0.084313  -0.165622       NaN        NaN            NaN
# 1        -0.278235   1.232726       NaN        NaN            NaN
# 2              NaN        NaN -0.501007  -0.095816      -0.427878
# 3        -1.266709   0.157523       NaN        NaN            NaN
# 4        -0.225141   1.230314       NaN        NaN            NaN
#
#    modalitySound  highArousal  positiveValence
# 0          False         True            False
# 1          False        False            False
# 2           True         True            False
# 3          False        False            False
# 4          False        False            False

# %%
vis['subID'].value_counts().sum()
# Out:
# 9862

# %%
aud['subID'].value_counts().sum()
# Out:
# 9768

# %%
merged['subID'].value_counts().sum()
# Out:
# 19630

# %% [markdown]
# ## Stimulus feature correlation matrices

# %%
shape_corr = pd.read_csv('../data/study_3/multilevel_shapeCorr.csv', index_col=0)
sound_corr = pd.read_csv('../data/study_3/multilevel_soundCorr.csv', index_col=0)

# %%
shape_labels = ['Corner count', 'Area', 'Convexity']
sound_labels = ['SC', 'Duration', '# Onsets', 'Onset Str.']

mask_shape = np.zeros_like(shape_corr, dtype=np.bool)
mask_shape[np.triu_indices_from(mask_shape)] = True
mask_sound = np.zeros_like(sound_corr, dtype=np.bool)
mask_sound[np.triu_indices_from(mask_sound)] = True

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3.75))
sns.heatmap(shape_corr, annot=True, mask=mask_shape, ax=ax1, vmin=-1, cmap="RdBu_r")
sns.heatmap(sound_corr.round(2), annot=True, mask=mask_sound, ax=ax2, vmin=-1, cmap="RdBu_r")

ax1.set_yticklabels(shape_labels, {'rotation': 0})
ax1.set_xticklabels(shape_labels[::-1])
ax1.set_title("Shape feature correlations")

ax2.set_yticklabels(sound_labels, {'rotation': 0})
ax2.set_xticklabels(sound_labels[::-1], {'rotation': 0})
ax2.set_title("Sound feature correlations")

plt.tight_layout()
plt.savefig('figure_7.pdf')

# %%
shape_labels = ['Corner count', 'Area', 'Convexity']

mask_shape = np.zeros_like(shape_corr, dtype=np.bool)
mask_shape[np.triu_indices_from(mask_shape)] = True

plt.figure(figsize=(6.5,5))
sns.heatmap(shape_corr, annot=True, mask=mask_shape, vmin=-1, cmap="RdBu_r")

plt.yticks(np.array([0,1,2])+.5, shape_labels, rotation=0)
plt.xticks(np.array([0,1,2])+.5, shape_labels[::-1])

plt.title("Shape feature correlations")
# Out:
# Text(0.5, 1, 'Shape feature correlations')

# %%
sound_labels = ['SC', 'Duration', '# Onsets', 'Onset Str.']

mask_sound = np.zeros_like(sound_corr, dtype=np.bool)
mask_sound[np.triu_indices_from(mask_sound)] = True

plt.figure(figsize=(6.5,5))
sns.heatmap(sound_corr.round(2), annot=True, mask=mask_sound, vmin=-1, cmap="RdBu_r")

plt.yticks(np.array([0,1,2,3])+.5, sound_labels, rotation=0)
plt.xticks(np.array([0,1,2,3])+.5, sound_labels[::-1])

plt.title("Sound feature correlations")
# Out:
# Text(0.5, 1, 'Sound feature correlations')

# %% [markdown]
# ## Hierarchical Bayesian models

# %% [markdown]
# ### Set model fitting parameters

# %%
# Use this cell for faster testing
samples = 10
chains = 1
n_splits = 2

# %%
# Use this cell for slow but reasonable results
samples = 1500
chains = 4
n_splits = 5

# %% [markdown]
# ### Multimodal
#
# Fit a single model including sounds and images with both positve and negative emotions. Include modality and valence conditions as predictors. Allow participants' slopes and intercepts to vary.

# %%
fold_data_big = bambi_cv(
    merged, 
    model_string = 'highArousal ~ bin*modalitySound*positiveValence', 
    model_dict = {
        'random': ['bin*modalitySound*positiveValence|subID'],
        'categorical': ['subID', 'modalitySound', 'positiveValence'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin:modalitySound[T.True]:positiveValence[T.True]|subID_offset, bin:modalitySound[T.True]:positiveValence[T.True]|subID_sd, bin:positiveValence[T.True]|subID_offset, bin:positiveValence[T.True]|subID_sd, bin:modalitySound[T.True]|subID_offset, bin:modalitySound[T.True]|subID_sd, bin|subID_offset, bin|subID_sd, modalitySound[T.True]:positiveValence[T.True]|subID_offset, modalitySound[T.True]:positiveValence[T.True]|subID_sd, positiveValence[T.True]|subID_offset, positiveValence[T.True]|subID_sd, modalitySound[T.True]|subID_offset, modalitySound[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, bin:modalitySound:positiveValence, bin:positiveValence, bin:modalitySound, bin, modalitySound:positiveValence, positiveValence, modalitySound, Intercept]
# INFO:pymc3:NUTS: [bin:modalitySound[T.True]:positiveValence[T.True]|subID_offset, bin:modalitySound[T.True]:positiveValence[T.True]|subID_sd, bin:positiveValence[T.True]|subID_offset, bin:positiveValence[T.True]|subID_sd, bin:modalitySound[T.True]|subID_offset, bin:modalitySound[T.True]|subID_sd, bin|subID_offset, bin|subID_sd, modalitySound[T.True]:positiveValence[T.True]|subID_offset, modalitySound[T.True]:positiveValence[T.True]|subID_sd, positiveValence[T.True]|subID_offset, positiveValence[T.True]|subID_sd, modalitySound[T.True]|subID_offset, modalitySound[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, bin:modalitySound:positiveValence, bin:positiveValence, bin:modalitySound, bin, modalitySound:positiveValence, positiveValence, modalitySound, Intercept]
# 100%|██████████| 510/510 [01:22<00:00,  7.07it/s]
# 100%|██████████| 510/510 [00:59<00:00,  6.98it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin:modalitySound[T.True]:positiveValence[T.True]|subID_offset, bin:modalitySound[T.True]:positiveValence[T.True]|subID_sd, bin:positiveValence[T.True]|subID_offset, bin:positiveValence[T.True]|subID_sd, bin:modalitySound[T.True]|subID_offset, bin:modalitySound[T.True]|subID_sd, bin|subID_offset, bin|subID_sd, modalitySound[T.True]:positiveValence[T.True]|subID_offset, modalitySound[T.True]:positiveValence[T.True]|subID_sd, positiveValence[T.True]|subID_offset, positiveValence[T.True]|subID_sd, modalitySound[T.True]|subID_offset, modalitySound[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, bin:modalitySound:positiveValence, bin:positiveValence, bin:modalitySound, bin, modalitySound:positiveValence, positiveValence, modalitySound, Intercept]
# INFO:pymc3:NUTS: [bin:modalitySound[T.True]:positiveValence[T.True]|subID_offset, bin:modalitySound[T.True]:positiveValence[T.True]|subID_sd, bin:positiveValence[T.True]|subID_offset, bin:positiveValence[T.True]|subID_sd, bin:modalitySound[T.True]|subID_offset, bin:modalitySound[T.True]|subID_sd, bin|subID_offset, bin|subID_sd, modalitySound[T.True]:positiveValence[T.True]|subID_offset, modalitySound[T.True]:positiveValence[T.True]|subID_sd, positiveValence[T.True]|subID_offset, positiveValence[T.True]|subID_sd, modalitySound[T.True]|subID_offset, modalitySound[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, bin:modalitySound:positiveValence, bin:positiveValence, bin:modalitySound, bin, modalitySound:positiveValence, positiveValence, modalitySound, Intercept]
# 100%|██████████| 510/510 [01:15<00:00,  7.43it/s]
# 100%|██████████| 510/510 [01:06<00:00,  7.22it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_big[0])
# Out:
# 0.7848188269135141

# %%
np.std(fold_data_big[0])
# Out:
# 0.0004591205513607144

# %%
plot_full_cv(
    fold_data_big[1], fold_data_big[3], 'bin', merged, 
    x_label="SC or corner count (z-scored)", y_label="probability(high arousal)", title="Multimodal (full model)", dpi=300
)

# %%
print(summary_table(fold_data_big[1]))
# Out:
# |                                                            |    M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:-----------------------------------------------------------|-----:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd                                                 | 0.37 | 0.09 |       0.21 |       0.55 |         43.31 |           1.08 |
# | Intercept                                                  | 0.13 | 0.1  |      -0.05 |       0.34 |         19.84 |           1.01 |
# | bin                                                        | 1.11 | 0.09 |       0.93 |       1.27 |          6.74 |           1.19 |
# | bin:modalitySound                                  | 0.65 | 0.16 |       0.34 |       0.96 |         26.21 |           0.97 |
# | bin:modalitySound:positiveValence          | 0.11 | 0.28 |      -0.41 |       0.74 |         26.59 |           0.96 |
# | bin:modalitySound:positiveValence\|subID_sd | 0.53 | 0.29 |       0.03 |       1.24 |       2591.08 |           1.03 |
# | bin:modalitySound\|subID_sd                         | 0.54 | 0.13 |       0.29 |       0.78 |         11.63 |           1.2  |
# | bin:positiveValence                                | 0.69 | 0.15 |       0.39 |       0.98 |         51.69 |           1.07 |
# | bin:positiveValence\|subID_sd                       | 0.17 | 0.15 |       0.01 |       0.56 |         11.98 |           1.03 |
# | bin\|subID_sd                                               | 0.39 | 0.07 |       0.28 |       0.52 |         27.38 |           1    |
# | modalitySound                                      | 0.52 | 0.23 |       0.13 |       0.94 |         21.11 |           0.96 |
# | modalitySound:positiveValence              | 0.25 | 0.47 |      -0.7  |       1.22 |         73.27 |           0.96 |
# | modalitySound:positiveValence\|subID_sd     | 1.27 | 0.36 |       0.6  |       1.92 |         10.69 |           1.15 |
# | modalitySound\|subID_sd                             | 0.82 | 0.15 |       0.58 |       1.1  |         19.57 |           0.95 |
# | positiveValence                                    | 0.3  | 0.23 |      -0.14 |       0.74 |         32.97 |           1    |
# | positiveValence\|subID_sd                           | 0.71 | 0.22 |       0.38 |       1.3  |         38.31 |           0.96 |

# %%
fold_data_big_bin = bambi_cv(
    merged, 
    model_string = 'highArousal ~ bin', 
    model_dict = {
        'random': ['bin|subID'],
        'categorical': ['subID'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# INFO:pymc3:NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# 100%|██████████| 510/510 [00:15<00:00, 32.52it/s]
# 100%|██████████| 510/510 [00:09<00:00, 55.74it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# INFO:pymc3:NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# 100%|██████████| 510/510 [00:15<00:00, 32.16it/s]
# 100%|██████████| 510/510 [00:09<00:00, 55.46it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_big_bin[0])
# Out:
# 0.7745293944279961

# %%
np.std(fold_data_big_bin[0])
# Out:
# 0.0008580443974524621

# %%
plot_full_cv(
    fold_data_big_bin[1], fold_data_big_bin[3], 'bin', merged, 
    x_label="SC or corner count (z-scored)", y_label="probability(high arousal)", title="Multimodal (SC)", dpi=300
)

# %%
print(summary_table(fold_data_big_bin[1]))
# Out:
# |              |    M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:-------------|-----:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd   | 0.43 | 0.06 |       0.31 |       0.56 |          8.77 |           1.21 |
# | Intercept    | 0.46 | 0.06 |       0.33 |       0.55 |          5.98 |           1.23 |
# | bin          | 1.58 | 0.07 |       1.47 |       1.72 |         23.67 |           0.95 |
# | bin\|subID_sd | 0.49 | 0.08 |       0.38 |       0.69 |         18.49 |           0.99 |

# %%
fold_data_big_modality = bambi_cv(
    merged, 
    model_string = 'highArousal ~ modalitySound', 
    model_dict = {
        'random': ['modalitySound|subID'],
        'categorical': ['subID', 'modalitySound'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [modalitySound[T.True]|subID_offset, modalitySound[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, modalitySound, Intercept]
# INFO:pymc3:NUTS: [modalitySound[T.True]|subID_offset, modalitySound[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, modalitySound, Intercept]
# 100%|██████████| 510/510 [00:20<00:00, 24.38it/s]
# 100%|██████████| 510/510 [00:15<00:00, 32.72it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [modalitySound[T.True]|subID_offset, modalitySound[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, modalitySound, Intercept]
# INFO:pymc3:NUTS: [modalitySound[T.True]|subID_offset, modalitySound[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, modalitySound, Intercept]
# 100%|██████████| 510/510 [00:21<00:00, 23.63it/s]
# 100%|██████████| 510/510 [00:16<00:00, 31.10it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_big_modality[0])
# Out:
# 0.576311225208383

# %%
np.std(fold_data_big_modality[0])
# Out:
# 0.000760654245903325

# %%
plot_full_cv(
    fold_data_big_modality[1], fold_data_big_modality[3], 'modalitySound', merged, 
    x_label="Modality (0=shape, 1=sound)", y_label="probability(high arousal)", title="Multimodal (modality only)"
)

# %%
print(summary_table(fold_data_big_modality[1]))
# Out:
# |                                |    M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:-------------------------------|-----:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd                     | 0.34 | 0.05 |       0.27 |       0.44 |         12.08 |           1.04 |
# | Intercept                      | 0.19 | 0.06 |       0.06 |       0.3  |         11.24 |           1.08 |
# | modalitySound          | 0.28 | 0.09 |       0.08 |       0.43 |         35.52 |           0.95 |
# | modalitySound\|subID_sd | 0.6  | 0.06 |       0.48 |       0.71 |         19.62 |           1.04 |

# %%
fold_data_big_valence = bambi_cv(
    merged, 
    model_string = 'highArousal ~ positiveValence', 
    model_dict = {
        'random': ['positiveValence|subID'],
        'categorical': ['subID', 'positiveValence'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits,
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [positiveValence[T.True]|subID_offset, positiveValence[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, positiveValence, Intercept]
# INFO:pymc3:NUTS: [positiveValence[T.True]|subID_offset, positiveValence[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, positiveValence, Intercept]
# 100%|██████████| 510/510 [00:19<00:00, 25.96it/s]
# 100%|██████████| 510/510 [00:11<00:00, 45.97it/s]
# The acceptance probability does not match the target. It is 0.31976290803285007, but should be close to 0.8. Try to increase the number of tuning steps.
# WARNING:pymc3:The acceptance probability does not match the target. It is 0.31976290803285007, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.6110221868938213, but should be close to 0.8. Try to increase the number of tuning steps.
# WARNING:pymc3:The acceptance probability does not match the target. It is 0.6110221868938213, but should be close to 0.8. Try to increase the number of tuning steps.
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [positiveValence[T.True]|subID_offset, positiveValence[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, positiveValence, Intercept]
# INFO:pymc3:NUTS: [positiveValence[T.True]|subID_offset, positiveValence[T.True]|subID_sd, 1|subID_offset, 1|subID_sd, positiveValence, Intercept]
# 100%|██████████| 510/510 [00:18<00:00, 27.19it/s]
# 100%|██████████| 510/510 [00:10<00:00, 49.81it/s]
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.5600304434564124, but should be close to 0.8. Try to increase the number of tuning steps.
# WARNING:pymc3:The acceptance probability does not match the target. It is 0.5600304434564124, but should be close to 0.8. Try to increase the number of tuning steps.
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_big_valence[0])
# Out:
# 0.5720311138593224

# %%
np.std(fold_data_big_valence[0])
# Out:
# 0.002088210107283217

# %%
plot_full_cv(
    fold_data_big_valence[1], fold_data_big_valence[3], 'positiveValence', merged, 
    x_label="Valence (0=negative, 1=positive)", y_label="probability(high arousal)", title="Multimodal (valence only)"
)

# %%
print(summary_table(fold_data_big_valence[1]))
# Out:
# |                                  |    M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:---------------------------------|-----:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd                       | 0.22 | 0.05 |       0.13 |       0.29 |          2.44 |           1.59 |
# | Intercept                        | 0.23 | 0.05 |       0.15 |       0.32 |          2.66 |           1.46 |
# | positiveValence          | 0.17 | 0.08 |       0.04 |       0.33 |          9.59 |           1.34 |
# | positiveValence\|subID_sd | 0.18 | 0.11 |       0.02 |       0.38 |          2.84 |           2.09 |

# %% [markdown]
# ### Vision

# %%
vis.head()
# Out:
#    subID stimFile stimType       bin   corners  spectralCentroid rating  \
# 0      1      LC0    image -0.534524 -0.534524               NaN  Angry
# 1      1     PS14    image -0.801773 -0.801773               NaN    Sad
# 2      1     LC14    image -1.069022 -1.069022               NaN    Sad
# 3      1      PS3    image -0.000027 -0.000027               NaN    Sad
# 4      1     PS10    image -0.267276 -0.267276               NaN  Angry
#
#    boundingBoxArea  areaRatio  duration  numOnsets  onsetStrength  \
# 0        -0.084313  -0.165622       NaN        NaN            NaN
# 1        -0.278235   1.232726       NaN        NaN            NaN
# 2        -1.266709   0.157523       NaN        NaN            NaN
# 3        -0.225141   1.230314       NaN        NaN            NaN
# 4         0.717056  -0.188020       NaN        NaN            NaN
#
#    modalitySound  highArousal  positiveValence
# 0          False         True            False
# 1          False        False            False
# 2          False        False            False
# 3          False        False            False
# 4          False         True            False

# %%
fold_data_vis = bambi_cv(
    vis, 
    model_string = 'highArousal ~ bin*areaRatio*boundingBoxArea', 
    model_dict = {
        'random': ['bin*areaRatio*boundingBoxArea|subID'],
        'categorical': ['subID'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin:areaRatio:boundingBoxArea|subID_offset, bin:areaRatio:boundingBoxArea|subID_sd, areaRatio:boundingBoxArea|subID_offset, areaRatio:boundingBoxArea|subID_sd, bin:boundingBoxArea|subID_offset, bin:boundingBoxArea|subID_sd, boundingBoxArea|subID_offset, boundingBoxArea|subID_sd, bin:areaRatio|subID_offset, bin:areaRatio|subID_sd, areaRatio|subID_offset, areaRatio|subID_sd, bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin:areaRatio:boundingBoxArea, areaRatio:boundingBoxArea, bin:boundingBoxArea, boundingBoxArea, bin:areaRatio, areaRatio, bin, Intercept]
# INFO:pymc3:NUTS: [bin:areaRatio:boundingBoxArea|subID_offset, bin:areaRatio:boundingBoxArea|subID_sd, areaRatio:boundingBoxArea|subID_offset, areaRatio:boundingBoxArea|subID_sd, bin:boundingBoxArea|subID_offset, bin:boundingBoxArea|subID_sd, boundingBoxArea|subID_offset, boundingBoxArea|subID_sd, bin:areaRatio|subID_offset, bin:areaRatio|subID_sd, areaRatio|subID_offset, areaRatio|subID_sd, bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin:areaRatio:boundingBoxArea, areaRatio:boundingBoxArea, bin:boundingBoxArea, boundingBoxArea, bin:areaRatio, areaRatio, bin, Intercept]
# 100%|██████████| 510/510 [00:26<00:00, 19.30it/s]
# 100%|██████████| 510/510 [00:18<00:00, 28.23it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin:areaRatio:boundingBoxArea|subID_offset, bin:areaRatio:boundingBoxArea|subID_sd, areaRatio:boundingBoxArea|subID_offset, areaRatio:boundingBoxArea|subID_sd, bin:boundingBoxArea|subID_offset, bin:boundingBoxArea|subID_sd, boundingBoxArea|subID_offset, boundingBoxArea|subID_sd, bin:areaRatio|subID_offset, bin:areaRatio|subID_sd, areaRatio|subID_offset, areaRatio|subID_sd, bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin:areaRatio:boundingBoxArea, areaRatio:boundingBoxArea, bin:boundingBoxArea, boundingBoxArea, bin:areaRatio, areaRatio, bin, Intercept]
# INFO:pymc3:NUTS: [bin:areaRatio:boundingBoxArea|subID_offset, bin:areaRatio:boundingBoxArea|subID_sd, areaRatio:boundingBoxArea|subID_offset, areaRatio:boundingBoxArea|subID_sd, bin:boundingBoxArea|subID_offset, bin:boundingBoxArea|subID_sd, boundingBoxArea|subID_offset, boundingBoxArea|subID_sd, bin:areaRatio|subID_offset, bin:areaRatio|subID_sd, areaRatio|subID_offset, areaRatio|subID_sd, bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin:areaRatio:boundingBoxArea, areaRatio:boundingBoxArea, bin:boundingBoxArea, boundingBoxArea, bin:areaRatio, areaRatio, bin, Intercept]
# 100%|██████████| 510/510 [00:28<00:00, 17.99it/s]
# 100%|██████████| 510/510 [00:17<00:00, 29.65it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_vis[0])
# Out:
# 0.8278245394978194

# %%
np.std(fold_data_vis[0])
# Out:
# 0.0028042637476166643

# %%
plot_full_cv(
    fold_data_vis[1], fold_data_vis[3], 'bin', vis, 
    x_label="Corner count (z-scored)", y_label="probability(high arousal)", title="Shapes (full model)"
)

# %%
print(summary_table(fold_data_vis[1]))
# Out:
# |                                        |     M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:---------------------------------------|------:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd                             |  0.8  | 0.11 |       0.64 |       1    |         11.29 |           1.08 |
# | Intercept                              |  0.59 | 0.16 |       0.34 |       0.83 |         10.7  |           1.34 |
# | areaRatio                              | -1.22 | 0.07 |      -1.36 |      -1.12 |         11.12 |           1.07 |
# | areaRatio:boundingBoxArea              | -0.41 | 0.06 |      -0.51 |      -0.29 |         24.62 |           0.99 |
# | areaRatio:boundingBoxArea\|subID_sd     |  0.15 | 0.09 |       0.01 |       0.31 |         21.12 |           0.97 |
# | areaRatio\|subID_sd                     |  0.34 | 0.07 |       0.2  |       0.46 |          6.44 |           1.26 |
# | bin                                    |  2.16 | 0.1  |       1.98 |       2.32 |         13.03 |           0.98 |
# | bin:areaRatio                          | -0.06 | 0.06 |      -0.17 |       0.05 |         97.65 |           0.96 |
# | bin:areaRatio:boundingBoxArea          | -0.05 | 0.07 |      -0.2  |       0.13 |         39.45 |           1.02 |
# | bin:areaRatio:boundingBoxArea\|subID_sd |  0.07 | 0.06 |       0    |       0.23 |         24.39 |           0.96 |
# | bin:areaRatio\|subID_sd                 |  0.14 | 0.09 |       0.01 |       0.31 |         10.61 |           1.11 |
# | bin:boundingBoxArea                    | -0.63 | 0.08 |      -0.8  |      -0.48 |         38.44 |           0.98 |
# | bin:boundingBoxArea\|subID_sd           |  0.09 | 0.04 |       0.02 |       0.16 |          3.68 |           1.3  |
# | bin\|subID_sd                           |  0.65 | 0.1  |       0.44 |       0.85 |         10.31 |           1.15 |
# | boundingBoxArea                        | -0.94 | 0.09 |      -1.13 |      -0.78 |         13.54 |           1    |
# | boundingBoxArea\|subID_sd               |  0.58 | 0.12 |       0.33 |       0.81 |         16.29 |           1.04 |

# %%
fold_data_vis_bin = bambi_cv(
    vis, 
    model_string = 'highArousal ~ bin', 
    model_dict = {
        'random': ['bin|subID'],
        'categorical': ['subID'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# INFO:pymc3:NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# 100%|██████████| 510/510 [00:07<00:00, 69.66it/s]
# 100%|██████████| 510/510 [00:05<00:00, 92.85it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# INFO:pymc3:NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# 100%|██████████| 510/510 [00:08<00:00, 62.71it/s]
# 100%|██████████| 510/510 [00:05<00:00, 91.71it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_vis_bin[0])
# Out:
# 0.7493415522094399

# %%
np.std(fold_data_vis_bin[0])
# Out:
# 0.0031939447479637506

# %%
plot_full_cv(
    fold_data_vis_bin[1], fold_data_vis_bin[3], 'bin', vis, 
    x_label="Corner count (z-scored)", y_label="probability(high arousal)", title="Shapes (SC only)"
)

# %%
print(summary_table(fold_data_vis_bin[1]))
# Out:
# |              |    M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:-------------|-----:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd   | 0.61 | 0.1  |       0.47 |       0.83 |         12.15 |           1.56 |
# | Intercept    | 0.29 | 0.09 |       0.14 |       0.43 |          2.59 |           1.49 |
# | bin          | 1.47 | 0.08 |       1.35 |       1.67 |         24.47 |           1.03 |
# | bin\|subID_sd | 0.59 | 0.08 |       0.45 |       0.73 |          9.08 |           1.12 |

# %%
fold_data_vis_ratio = bambi_cv(
    vis, 
    model_string = 'highArousal ~ areaRatio', 
    model_dict = {
        'random': ['areaRatio|subID'],
        'categorical': ['subID'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [areaRatio|subID_offset, areaRatio|subID_sd, 1|subID_offset, 1|subID_sd, areaRatio, Intercept]
# INFO:pymc3:NUTS: [areaRatio|subID_offset, areaRatio|subID_sd, 1|subID_offset, 1|subID_sd, areaRatio, Intercept]
# 100%|██████████| 510/510 [00:07<00:00, 66.51it/s]
# 100%|██████████| 510/510 [00:05<00:00, 92.33it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [areaRatio|subID_offset, areaRatio|subID_sd, 1|subID_offset, 1|subID_sd, areaRatio, Intercept]
# INFO:pymc3:NUTS: [areaRatio|subID_offset, areaRatio|subID_sd, 1|subID_offset, 1|subID_sd, areaRatio, Intercept]
# 100%|██████████| 510/510 [00:07<00:00, 67.09it/s]
# 100%|██████████| 510/510 [00:05<00:00, 99.55it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_vis_ratio[0])
# Out:
# 0.6780573610432511

# %%
np.std(fold_data_vis_ratio[0])
# Out:
# 0.0008473042711505396

# %%
plot_full_cv(
    fold_data_vis_ratio[1], fold_data_vis_ratio[3], 'areaRatio', vis, 
    x_label="Convexity (z-scored)", y_label="probability(high arousal)", title="Shapes (convexity only)"
)

# %%
print(summary_table(fold_data_vis_ratio[1]))
# Out:
# |                    |     M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:-------------------|------:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd         |  0.43 | 0.06 |       0.35 |       0.57 |         10.31 |           1.18 |
# | Intercept          |  0.21 | 0.1  |       0.03 |       0.42 |         18.04 |           0.95 |
# | areaRatio          | -0.84 | 0.06 |      -0.98 |      -0.75 |         25.04 |           0.98 |
# | areaRatio\|subID_sd |  0.26 | 0.06 |       0.16 |       0.37 |         13.08 |           1.03 |

# %%
fold_data_vis_area = bambi_cv(
    vis, 
    model_string = 'highArousal ~ boundingBoxArea', 
    model_dict = {
        'random': ['boundingBoxArea|subID'],
        'categorical': ['subID'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [boundingBoxArea|subID_offset, boundingBoxArea|subID_sd, 1|subID_offset, 1|subID_sd, boundingBoxArea, Intercept]
# INFO:pymc3:NUTS: [boundingBoxArea|subID_offset, boundingBoxArea|subID_sd, 1|subID_offset, 1|subID_sd, boundingBoxArea, Intercept]
# 100%|██████████| 510/510 [00:07<00:00, 71.33it/s]
# 100%|██████████| 510/510 [00:05<00:00, 99.34it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='True'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [boundingBoxArea|subID_offset, boundingBoxArea|subID_sd, 1|subID_offset, 1|subID_sd, boundingBoxArea, Intercept]
# INFO:pymc3:NUTS: [boundingBoxArea|subID_offset, boundingBoxArea|subID_sd, 1|subID_offset, 1|subID_sd, boundingBoxArea, Intercept]
# 100%|██████████| 510/510 [00:06<00:00, 74.30it/s]
# 100%|██████████| 510/510 [00:04<00:00, 102.14it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_vis_area[0])
# Out:
# 0.6073813601285803

# %%
np.std(fold_data_vis_area[0])
# Out:
# 0.0025132059703653065

# %%
plot_full_cv(
    fold_data_vis_area[1], fold_data_vis_area[3], 'boundingBoxArea', vis, 
    x_label="Bounding box area (z-scored)", y_label="probability(high arousal)", title="Shapes (bounding box area only)"
)

# %%
print(summary_table(fold_data_vis_area[1]))
# Out:
# |                          |     M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:-------------------------|------:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd               |  0.4  | 0.05 |       0.32 |       0.5  |         11.46 |           1.01 |
# | Intercept                |  0.17 | 0.07 |       0.06 |       0.3  |          6.98 |           1.13 |
# | boundingBoxArea          | -0.2  | 0.06 |      -0.32 |      -0.11 |         36.24 |           0.96 |
# | boundingBoxArea\|subID_sd |  0.42 | 0.04 |       0.35 |       0.51 |         16.7  |           1.01 |

# %% [markdown]
# ### Audition

# %%
aud.head()
# Out:
#    subID stimFile stimType       bin  corners  spectralCentroid rating  \
# 0      1     ROS3    sound -1.628827      NaN         -1.528469  Angry
# 1      1     ROS5    sound -0.821644      NaN         -0.909950    Sad
# 2      1     SAW7    sound -0.283522      NaN         -0.310462    Sad
# 3      1     SAW4    sound  0.254600      NaN          0.179809    Sad
# 4      1     SAW4    sound -0.552583      NaN         -0.608187    Sad
#
#    boundingBoxArea  areaRatio  duration  numOnsets  onsetStrength  \
# 0              NaN        NaN -0.501007  -0.095816      -0.427878
# 1              NaN        NaN  0.189094   0.590003       0.072391
# 2              NaN        NaN  0.884946  -1.309188      -1.116304
# 3              NaN        NaN -0.155956  -0.676124      -1.018107
# 4              NaN        NaN -0.155956  -0.359593      -0.911477
#
#    modalitySound  highArousal  positiveValence
# 0           True            1            False
# 1           True            0            False
# 2           True            0            False
# 3           True            0            False
# 4           True            0            False

# %%
fold_data_aud = bambi_cv(
    aud, 
    model_string = 'highArousal ~ bin*duration*numOnsets*onsetStrength', 
    model_dict = {
        'random': ['bin*duration*numOnsets*onsetStrength|subID'],
        'categorical': ['subID'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='1'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin:duration:numOnsets:onsetStrength|subID_offset, bin:duration:numOnsets:onsetStrength|subID_sd, duration:numOnsets:onsetStrength|subID_offset, duration:numOnsets:onsetStrength|subID_sd, bin:numOnsets:onsetStrength|subID_offset, bin:numOnsets:onsetStrength|subID_sd, numOnsets:onsetStrength|subID_offset, numOnsets:onsetStrength|subID_sd, bin:duration:onsetStrength|subID_offset, bin:duration:onsetStrength|subID_sd, duration:onsetStrength|subID_offset, duration:onsetStrength|subID_sd, bin:onsetStrength|subID_offset, bin:onsetStrength|subID_sd, onsetStrength|subID_offset, onsetStrength|subID_sd, bin:duration:numOnsets|subID_offset, bin:duration:numOnsets|subID_sd, duration:numOnsets|subID_offset, duration:numOnsets|subID_sd, bin:numOnsets|subID_offset, bin:numOnsets|subID_sd, numOnsets|subID_offset, numOnsets|subID_sd, bin:duration|subID_offset, bin:duration|subID_sd, duration|subID_offset, duration|subID_sd, bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin:duration:numOnsets:onsetStrength, duration:numOnsets:onsetStrength, bin:numOnsets:onsetStrength, numOnsets:onsetStrength, bin:duration:onsetStrength, duration:onsetStrength, bin:onsetStrength, onsetStrength, bin:duration:numOnsets, duration:numOnsets, bin:numOnsets, numOnsets, bin:duration, duration, bin, Intercept]
# INFO:pymc3:NUTS: [bin:duration:numOnsets:onsetStrength|subID_offset, bin:duration:numOnsets:onsetStrength|subID_sd, duration:numOnsets:onsetStrength|subID_offset, duration:numOnsets:onsetStrength|subID_sd, bin:numOnsets:onsetStrength|subID_offset, bin:numOnsets:onsetStrength|subID_sd, numOnsets:onsetStrength|subID_offset, numOnsets:onsetStrength|subID_sd, bin:duration:onsetStrength|subID_offset, bin:duration:onsetStrength|subID_sd, duration:onsetStrength|subID_offset, duration:onsetStrength|subID_sd, bin:onsetStrength|subID_offset, bin:onsetStrength|subID_sd, onsetStrength|subID_offset, onsetStrength|subID_sd, bin:duration:numOnsets|subID_offset, bin:duration:numOnsets|subID_sd, duration:numOnsets|subID_offset, duration:numOnsets|subID_sd, bin:numOnsets|subID_offset, bin:numOnsets|subID_sd, numOnsets|subID_offset, numOnsets|subID_sd, bin:duration|subID_offset, bin:duration|subID_sd, duration|subID_offset, duration|subID_sd, bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin:duration:numOnsets:onsetStrength, duration:numOnsets:onsetStrength, bin:numOnsets:onsetStrength, numOnsets:onsetStrength, bin:duration:onsetStrength, duration:onsetStrength, bin:onsetStrength, onsetStrength, bin:duration:numOnsets, duration:numOnsets, bin:numOnsets, numOnsets, bin:duration, duration, bin, Intercept]
# 100%|██████████| 510/510 [01:10<00:00, 11.99it/s]
# 100%|██████████| 510/510 [00:49<00:00, 11.36it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='1'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin:duration:numOnsets:onsetStrength|subID_offset, bin:duration:numOnsets:onsetStrength|subID_sd, duration:numOnsets:onsetStrength|subID_offset, duration:numOnsets:onsetStrength|subID_sd, bin:numOnsets:onsetStrength|subID_offset, bin:numOnsets:onsetStrength|subID_sd, numOnsets:onsetStrength|subID_offset, numOnsets:onsetStrength|subID_sd, bin:duration:onsetStrength|subID_offset, bin:duration:onsetStrength|subID_sd, duration:onsetStrength|subID_offset, duration:onsetStrength|subID_sd, bin:onsetStrength|subID_offset, bin:onsetStrength|subID_sd, onsetStrength|subID_offset, onsetStrength|subID_sd, bin:duration:numOnsets|subID_offset, bin:duration:numOnsets|subID_sd, duration:numOnsets|subID_offset, duration:numOnsets|subID_sd, bin:numOnsets|subID_offset, bin:numOnsets|subID_sd, numOnsets|subID_offset, numOnsets|subID_sd, bin:duration|subID_offset, bin:duration|subID_sd, duration|subID_offset, duration|subID_sd, bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin:duration:numOnsets:onsetStrength, duration:numOnsets:onsetStrength, bin:numOnsets:onsetStrength, numOnsets:onsetStrength, bin:duration:onsetStrength, duration:onsetStrength, bin:onsetStrength, onsetStrength, bin:duration:numOnsets, duration:numOnsets, bin:numOnsets, numOnsets, bin:duration, duration, bin, Intercept]
# INFO:pymc3:NUTS: [bin:duration:numOnsets:onsetStrength|subID_offset, bin:duration:numOnsets:onsetStrength|subID_sd, duration:numOnsets:onsetStrength|subID_offset, duration:numOnsets:onsetStrength|subID_sd, bin:numOnsets:onsetStrength|subID_offset, bin:numOnsets:onsetStrength|subID_sd, numOnsets:onsetStrength|subID_offset, numOnsets:onsetStrength|subID_sd, bin:duration:onsetStrength|subID_offset, bin:duration:onsetStrength|subID_sd, duration:onsetStrength|subID_offset, duration:onsetStrength|subID_sd, bin:onsetStrength|subID_offset, bin:onsetStrength|subID_sd, onsetStrength|subID_offset, onsetStrength|subID_sd, bin:duration:numOnsets|subID_offset, bin:duration:numOnsets|subID_sd, duration:numOnsets|subID_offset, duration:numOnsets|subID_sd, bin:numOnsets|subID_offset, bin:numOnsets|subID_sd, numOnsets|subID_offset, numOnsets|subID_sd, bin:duration|subID_offset, bin:duration|subID_sd, duration|subID_offset, duration|subID_sd, bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin:duration:numOnsets:onsetStrength, duration:numOnsets:onsetStrength, bin:numOnsets:onsetStrength, numOnsets:onsetStrength, bin:duration:onsetStrength, duration:onsetStrength, bin:onsetStrength, onsetStrength, bin:duration:numOnsets, duration:numOnsets, bin:numOnsets, numOnsets, bin:duration, duration, bin, Intercept]
# 100%|██████████| 510/510 [01:12<00:00,  6.99it/s]
# 100%|██████████| 510/510 [00:50<00:00, 10.04it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_aud[0])
# Out:
# 0.8327079016686599

# %%
np.std(fold_data_aud[0])
# Out:
# 0.006826031283098

# %%
plot_full_cv(
    fold_data_aud[1], fold_data_aud[3], 'bin', aud, 
    x_label="SC (z-scored)", y_label="probability(high arousal)", title="Sounds (full model)"
)

# %%
print(summary_table(fold_data_aud[1]))
# Out:
# |                                               |     M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:----------------------------------------------|------:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd                                    |  0.95 | 0.13 |       0.73 |       1.2  |         14.61 |           0.97 |
# | Intercept                                     |  1.07 | 0.16 |       0.74 |       1.33 |          2.55 |           1.5  |
# | bin                                           |  2.23 | 0.11 |       2.02 |       2.43 |         20.02 |           0.98 |
# | bin:duration                                  | -0.33 | 0.11 |      -0.48 |      -0.12 |          4.93 |           1.27 |
# | bin:duration:numOnsets                        | -0.05 | 0.08 |      -0.19 |       0.1  |         15.49 |           1.05 |
# | bin:duration:numOnsets:onsetStrength          | -0.16 | 0.1  |      -0.34 |       0.03 |         32.26 |           1.1  |
# | bin:duration:numOnsets:onsetStrength\|subID_sd |  0.18 | 0.09 |       0.06 |       0.45 |         24.38 |           0.98 |
# | bin:duration:numOnsets\|subID_sd               |  0.19 | 0.1  |       0.04 |       0.41 |         11.71 |           1.02 |
# | bin:duration:onsetStrength                    | -0.39 | 0.12 |      -0.6  |      -0.18 |          6.76 |           1.27 |
# | bin:duration:onsetStrength\|subID_sd           |  0.17 | 0.08 |       0.03 |       0.32 |         19.56 |           1.05 |
# | bin:duration\|subID_sd                         |  0.09 | 0.07 |       0.01 |       0.23 |         25.21 |           0.99 |
# | bin:numOnsets                                 |  0.6  | 0.14 |       0.32 |       0.8  |          6.79 |           1.18 |
# | bin:numOnsets:onsetStrength                   |  0.81 | 0.17 |       0.47 |       1.07 |          9.52 |           1.19 |
# | bin:numOnsets:onsetStrength\|subID_sd          |  0.2  | 0.1  |       0.03 |       0.4  |          4.11 |           1.23 |
# | bin:numOnsets\|subID_sd                        |  0.12 | 0.07 |       0.02 |       0.23 |         11.33 |           1.06 |
# | bin:onsetStrength                             | -0.16 | 0.16 |      -0.46 |       0.11 |         42.9  |           0.95 |
# | bin:onsetStrength\|subID_sd                    |  0.57 | 0.11 |       0.39 |       0.8  |          8.23 |           1.24 |
# | bin\|subID_sd                                  |  0.61 | 0.09 |       0.45 |       0.77 |         11.84 |           1.08 |
# | duration                                      | -0.03 | 0.09 |      -0.19 |       0.14 |         15.91 |           0.99 |
# | duration:numOnsets                            | -0.03 | 0.06 |      -0.14 |       0.08 |       -109.55 |           0.96 |
# | duration:numOnsets:onsetStrength              | -0.12 | 0.06 |      -0.25 |      -0.01 |         16.1  |           1.02 |
# | duration:numOnsets:onsetStrength\|subID_sd     |  0.12 | 0.05 |       0.05 |       0.23 |         11.68 |           1.15 |
# | duration:numOnsets\|subID_sd                   |  0.05 | 0.04 |       0    |       0.19 |         10.78 |           1.01 |
# | duration:onsetStrength                        | -0.17 | 0.11 |      -0.35 |      -0.03 |         14.73 |           1    |
# | duration:onsetStrength\|subID_sd               |  0.17 | 0.08 |       0.02 |       0.4  |         10    |           1.13 |
# | duration\|subID_sd                             |  0.11 | 0.07 |       0.01 |       0.24 |          3.9  |           1.52 |
# | numOnsets                                     |  0.12 | 0.11 |      -0.13 |       0.29 |         19.29 |           1.02 |
# | numOnsets:onsetStrength                       |  0.44 | 0.12 |       0.24 |       0.64 |         14.19 |           1.04 |
# | numOnsets:onsetStrength\|subID_sd              |  0.19 | 0.09 |       0.01 |       0.37 |         23.6  |           0.95 |
# | numOnsets\|subID_sd                            |  0.08 | 0.04 |       0.01 |       0.15 |          9.44 |           1.06 |
# | onsetStrength                                 |  0.69 | 0.12 |       0.54 |       0.96 |         14.53 |           1.11 |
# | onsetStrength\|subID_sd                        |  0.59 | 0.1  |       0.41 |       0.82 |         10.29 |           1.09 |

# %%
fold_data_aud_bin = bambi_cv(
    aud, 
    model_string = 'highArousal ~ bin', 
    model_dict = {
        'random': ['bin|subID'],
        'categorical': ['subID'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='1'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# INFO:pymc3:NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# 100%|██████████| 510/510 [00:08<00:00, 59.71it/s]
# 100%|██████████| 510/510 [00:05<00:00, 101.13it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='1'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# INFO:pymc3:NUTS: [bin|subID_offset, bin|subID_sd, 1|subID_offset, 1|subID_sd, bin, Intercept]
# 100%|██████████| 510/510 [00:09<00:00, 56.65it/s]
# 100%|██████████| 510/510 [00:05<00:00, 96.87it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_aud_bin[0])
# Out:
# 0.8189018148865369

# %%
np.std(fold_data_aud_bin[0])
# Out:
# 0.0020579882307724118

# %%
plot_full_cv(
    fold_data_aud_bin[1], fold_data_aud_bin[3], 'bin', aud, 
    x_label="SC (z-scored)", y_label="probability(high arousal)", title="Sounds (SC only)"
)

# %%
print(summary_table(fold_data_aud_bin[1]))
# Out:
# |              |    M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:-------------|-----:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd   | 0.95 | 0.1  |       0.76 |       1.18 |          4.05 |           1.38 |
# | Intercept    | 0.97 | 0.13 |       0.72 |       1.18 |          8.6  |           1.08 |
# | bin          | 2.11 | 0.11 |       1.91 |       2.32 |         13.95 |           0.95 |
# | bin\|subID_sd | 0.59 | 0.11 |       0.42 |       0.83 |         10.9  |           1    |

# %%
fold_data_aud_duration = bambi_cv(
    aud, 
    model_string = 'highArousal ~ duration', 
    model_dict = {
        'random': ['duration|subID'],
        'categorical': ['subID'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='1'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [duration|subID_offset, duration|subID_sd, 1|subID_offset, 1|subID_sd, duration, Intercept]
# INFO:pymc3:NUTS: [duration|subID_offset, duration|subID_sd, 1|subID_offset, 1|subID_sd, duration, Intercept]
# 100%|██████████| 510/510 [00:08<00:00, 61.05it/s]
# 100%|██████████| 510/510 [00:04<00:00, 102.88it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='1'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [duration|subID_offset, duration|subID_sd, 1|subID_offset, 1|subID_sd, duration, Intercept]
# INFO:pymc3:NUTS: [duration|subID_offset, duration|subID_sd, 1|subID_offset, 1|subID_sd, duration, Intercept]
# 100%|██████████| 510/510 [00:07<00:00, 64.31it/s]
# 100%|██████████| 510/510 [00:05<00:00, 100.31it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_aud_duration[0])
# Out:
# 0.6023686694118807

# %%
np.std(fold_data_aud_duration[0])
# Out:
# 0.003927324046827385

# %%
plot_full_cv(
    fold_data_aud_duration[1], fold_data_aud_duration[3], 'duration', aud, 
    x_label="Duration (z-scored)", y_label="probability(high arousal)", title="Sounds (duration only)"
)

# %%
print(summary_table(fold_data_aud_duration[1]))
# Out:
# |                   |    M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:------------------|-----:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd        | 0.48 | 0.06 |       0.37 |       0.64 |          5.92 |           1.34 |
# | Intercept         | 0.49 | 0.06 |       0.37 |       0.59 |          4.51 |           1.15 |
# | duration          | 0.01 | 0.03 |      -0.05 |       0.07 |         -4.8  |           0.96 |
# | duration\|subID_sd | 0.07 | 0.04 |       0.02 |       0.15 |          8.87 |           1.14 |

# %%
fold_data_aud_onsets = bambi_cv(
    aud, 
    model_string = 'highArousal ~ numOnsets', 
    model_dict = {
        'random': ['numOnsets|subID'],
        'categorical': ['subID'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='1'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [numOnsets|subID_offset, numOnsets|subID_sd, 1|subID_offset, 1|subID_sd, numOnsets, Intercept]
# INFO:pymc3:NUTS: [numOnsets|subID_offset, numOnsets|subID_sd, 1|subID_offset, 1|subID_sd, numOnsets, Intercept]
# 100%|██████████| 510/510 [00:08<00:00, 63.39it/s]
# 100%|██████████| 510/510 [00:05<00:00, 100.93it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='1'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [numOnsets|subID_offset, numOnsets|subID_sd, 1|subID_offset, 1|subID_sd, numOnsets, Intercept]
# INFO:pymc3:NUTS: [numOnsets|subID_offset, numOnsets|subID_sd, 1|subID_offset, 1|subID_sd, numOnsets, Intercept]
# 100%|██████████| 510/510 [00:07<00:00, 66.11it/s]
# 100%|██████████| 510/510 [00:05<00:00, 101.17it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_aud_onsets[0])
# Out:
# 0.6019745954789155

# %%
np.std(fold_data_aud_onsets[0])
# Out:
# 0.005490539877934353

# %%
plot_full_cv(
    fold_data_aud_onsets[1], fold_data_aud_onsets[3], 'numOnsets', aud, 
    x_label="Number of onsets (z-scored)", y_label="probability(high arousal)", title="Sounds (number of onsets only)"
)

# %%
print(summary_table(fold_data_aud_onsets[1]))
# Out:
# |                    |     M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:-------------------|------:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd         |  0.46 | 0.07 |       0.36 |       0.6  |         21.11 |           0.95 |
# | Intercept          |  0.47 | 0.07 |       0.37 |       0.63 |         14.15 |           1.12 |
# | numOnsets          | -0.05 | 0.04 |      -0.13 |       0.02 |        -45.05 |           1.08 |
# | numOnsets\|subID_sd |  0.16 | 0.05 |       0.08 |       0.25 |          8.92 |           1.16 |

# %%
fold_data_aud_strength = bambi_cv(
    aud, 
    model_string = 'highArousal ~ onsetStrength', 
    model_dict = {
        'random': ['onsetStrength|subID'],
        'categorical': ['subID'],
        'family': 'bernoulli', 
        'samples': samples, 
        'chains': chains, 
        'init': None,
        'compute_convergence_checks': False
    }, 
    n_splits=n_splits
)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='1'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [onsetStrength|subID_offset, onsetStrength|subID_sd, 1|subID_offset, 1|subID_sd, onsetStrength, Intercept]
# INFO:pymc3:NUTS: [onsetStrength|subID_offset, onsetStrength|subID_sd, 1|subID_offset, 1|subID_sd, onsetStrength, Intercept]
# 100%|██████████| 510/510 [00:07<00:00, 66.95it/s]
# 100%|██████████| 510/510 [00:05<00:00, 97.41it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/bambi/models.py:230: UserWarning: Modeling the probability that highArousal=='1'
#   self.y.name, str(self.clean_data[self.y.name].iloc[event])))
# Only 10 samples in chain.
# WARNING:pymc3:Only 10 samples in chain.
# Sequential sampling (2 chains in 1 job)
# INFO:pymc3:Sequential sampling (2 chains in 1 job)
# NUTS: [onsetStrength|subID_offset, onsetStrength|subID_sd, 1|subID_offset, 1|subID_sd, onsetStrength, Intercept]
# INFO:pymc3:NUTS: [onsetStrength|subID_offset, onsetStrength|subID_sd, 1|subID_offset, 1|subID_sd, onsetStrength, Intercept]
# 100%|██████████| 510/510 [00:07<00:00, 103.75it/s]
# 100%|██████████| 510/510 [00:05<00:00, 90.58it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
np.mean(fold_data_aud_strength[0])
# Out:
# 0.6337029131957417

# %%
np.std(fold_data_aud_strength[0])
# Out:
# 0.0006285060003206611

# %%
plot_full_cv(
    fold_data_aud_strength[1], fold_data_aud_strength[3], 'onsetStrength', aud, 
    x_label="Onset strength (z-scored)", y_label="probability(high arousal)", title="Sounds (onset strength only)"
)

# %%
print(summary_table(fold_data_aud_strength[1]))
# Out:
# |                        |    M |   SD |   CI lower |   CI upper |   Effective N |   Gelman-Rubin |
# |:-----------------------|-----:|-----:|-----------:|-----------:|--------------:|---------------:|
# | 1\|subID_sd             | 0.55 | 0.06 |       0.45 |       0.67 |         44.41 |           0.98 |
# | Intercept              | 0.52 | 0.09 |       0.33 |       0.66 |         37.97 |           1.01 |
# | onsetStrength          | 0.61 | 0.05 |       0.53 |       0.71 |      -1057.1  |           0.98 |
# | onsetStrength\|subID_sd | 0.31 | 0.05 |       0.23 |       0.41 |         10.58 |           1.04 |

# %% [markdown]
# ## Model accuracy summaries

# %%
import itertools

# %%
multimodal = [
    fold_data_big,
    fold_data_big_bin,
    fold_data_big_modality,
    fold_data_big_valence
]
shapes = [
    fold_data_vis,
    fold_data_vis_bin,
    fold_data_vis_ratio,
    fold_data_vis_area
]
sounds = [
    fold_data_aud,
    fold_data_aud_bin,
    fold_data_aud_strength,
    fold_data_aud_duration,
    fold_data_aud_onsets
]

# %%
pd.DataFrame({
    'Model': (
        ['Shapes, full'] * n_splits + 
        ['Shapes, corner count'] * n_splits + 
        ['Shapes, convexity'] * n_splits + 
        ['Shapes, area'] * n_splits
    ),
    'Modality': ['Shapes'] * 4 * n_splits,
    'Accuracy': list(itertools.chain.from_iterable([fd[0] for fd in shapes])),
    'AUC': list(itertools.chain.from_iterable([fd[4] for fd in shapes]))
})
# Out:
#                   Model Modality  Accuracy       AUC
# 0          Shapes, full   Shapes  0.825020  0.911786
# 1          Shapes, full   Shapes  0.830629  0.912791
# 2  Shapes, corner count   Shapes  0.746148  0.823236
# 3  Shapes, corner count   Shapes  0.752535  0.832560
# 4     Shapes, convexity   Shapes  0.677210  0.728274
# 5     Shapes, convexity   Shapes  0.678905  0.723717
# 6          Shapes, area   Shapes  0.609895  0.646597
# 7          Shapes, area   Shapes  0.604868  0.627631

# %%
summary_df = pd.DataFrame({
    'Model': (
        ['Multimodal, full'] * n_splits + 
        ['Multimodal, SC'] * n_splits + 
        ['Multimodal, modality'] * n_splits + 
        ['Multimodal, valence'] * n_splits
    ),
    'Modality': ['Multimodal'] * 4 * n_splits,
    'Accuracy': list(itertools.chain.from_iterable([fd[0] for fd in multimodal])),
    'AUC': list(itertools.chain.from_iterable([fd[4] for fd in multimodal]))
}).append(pd.DataFrame({
    'Model': (
        ['Shapes, full'] * n_splits + 
        ['Shapes, corner count'] * n_splits + 
        ['Shapes, convexity'] * n_splits + 
        ['Shapes, area'] * n_splits
    ),
    'Modality': ['Shapes'] * 4 * n_splits,
    'Accuracy': list(itertools.chain.from_iterable([fd[0] for fd in shapes])),
    'AUC': list(itertools.chain.from_iterable([fd[4] for fd in shapes]))
})).append(pd.DataFrame({
    'Model': (
        ['Sounds, full'] * n_splits + 
        ['Sounds, SC'] * n_splits + 
        ['Sounds, mean onset strength'] * n_splits + 
        ['Sounds, # onsets'] * n_splits + 
        ['Sounds, duration'] * n_splits
    ),
    'Modality': ['Sounds'] * n_splits * 5,
    'Accuracy': list(itertools.chain.from_iterable([fd[0] for fd in sounds])),
    'AUC': list(itertools.chain.from_iterable([fd[4] for fd in sounds]))
}))

# %%
summary_df.head().round(2)
# Out:
#                   Model    Modality  Accuracy   AUC
# 0      Multimodal, full  Multimodal      0.79  0.86
# 1      Multimodal, full  Multimodal      0.78  0.86
# 2        Multimodal, SC  Multimodal      0.77  0.84
# 3        Multimodal, SC  Multimodal      0.78  0.84
# 4  Multimodal, modality  Multimodal      0.58  0.59

# %%
chance_merged = (merged['highArousal'].value_counts() / merged.shape[0]).max()
chance_vis = (vis['highArousal'].value_counts() / vis.shape[0]).max()
chance_aud = (aud['highArousal'].value_counts() / aud.shape[0]).max()

# %%
chance_merged
# Out:
# 0.5721344880285277

# %%
sns.set_context('notebook', font_scale=1.5)
colors = sns.color_palette("Set2", 10)
g = sns.barplot(
    y='Model', 
    x='Accuracy', 
    palette=[colors[2]] * 4 + [colors[3]] * 4 + [colors[0]] * 5,
    orient='h',
    data=summary_df
)
plt.plot([chance_merged] * 2, [-.5, 3.5], '--', c='black')
plt.plot([chance_vis] * 2, [3.5, 7.5], '--', c='black')
plt.plot([chance_aud] * 2, [7.5, 13.5], '--', c='black')

plt.xlim((0.5, .85))
plt.xlabel("Accuracy")
plt.title("Comparison of cross-validated model accuracies")
sns.despine(left=True, bottom=True)

# %% [markdown]
# ## Posterior predictive check, cross-validated

# %%
def ppc_cv(models, source_df, param='highArousal'):
    fold_ppc = []
    fold_ppc_mean = []
    fold_ppc_mean_sd = []
    fold_ppc_sd = []
    fold_ppc_sd_sd = []
    fold_test_mean = []
    fold_test_sd = []
    
    for model in models:
        test_data = source_df.drop(model.data.index, axis=0)
        ppc = pm.sample_ppc(
            model.backend.trace,
            samples=500,
            model=model.backend.model
        )
        
        fold_ppc.append(ppc)
        fold_ppc_mean.append(np.mean([n.mean() for n in ppc[param]]))
        fold_ppc_mean_sd.append(np.std([n.mean() for n in ppc[param]]))
        fold_ppc_sd.append(np.mean([n.std() for n in ppc[param]]))
        fold_ppc_sd_sd.append(np.std([n.std() for n in ppc[param]]))
        fold_test_mean.append(test_data[param].mean())
        fold_test_sd.append(test_data[param].std())
    
    return {
        'ppc': fold_ppc,
        'ppc_mean': np.array(fold_ppc_mean),
        'ppc_mean_sd': np.array(fold_ppc_mean_sd),
        'ppc_sd': np.array(fold_ppc_sd),
        'ppc_sd_sd': np.array(fold_ppc_sd_sd),
        'test_mean': np.array(fold_test_mean),
        'test_sd': np.array(fold_test_sd)
    }

# %%
def discrepancy_cv(ppc_dict):
    d_mean = np.mean(ppc_dict['ppc_mean'] - ppc_dict['test_mean'])
    d_sd = np.mean(ppc_dict['ppc_sd'] - ppc_dict['test_sd'])
    return (d_mean, d_sd)

# %%
ppc = ppc_cv(fold_data_aud_strength[2], aud)
discrepancy_cv(ppc)
# Out:
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: sample_ppc() is deprecated.  Please use sample_posterior_predictive()
#   from ipykernel import kernelapp as app
# 100%|██████████| 500/500 [00:02<00:00, 204.21it/s]
# /Users/beau/miniconda3/envs/multisensory_arousal/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: sample_ppc() is deprecated.  Please use sample_posterior_predictive()
#   from ipykernel import kernelapp as app
# 100%|██████████| 500/500 [00:00<00:00, 868.89it/s]
# (-0.0015587639695016642, 0.00019866624061981586)

# %%
ax = plt.subplot()
sns.distplot([n.mean() for n in ppc['ppc'][0]['highArousal']], kde=False, ax=ax)
ax.axvline(merged['highArousal'].mean())
